# %% [markdown]
# # 1. Zero-Shot Prompting - Prompts Sin Ejemplos Previos
#
# ## Objetivos de Aprendizaje
# - Comprender los principios del zero-shot prompting
# - Diseñar prompts efectivos sin ejemplos previos
# - Aplicar técnicas de instrucción clara y contexto
# - Evaluar la efectividad de diferentes enfoques zero-shot
#
# ## ¿Qué es Zero-Shot Prompting?
#
# Zero-shot prompting es la técnica donde pedimos al modelo realizar una tarea **sin proporcionar ejemplos específicos** de cómo debe hacerla. El modelo debe basarse únicamente en:
# - Su entrenamiento previo
# - Las instrucciones que le damos
# - El contexto que proporcionamos
#
# ### Ventajas:
# - **Simplicidad**: No requiere crear ejemplos
# - **Flexibilidad**: Fácil de adaptar a nuevas tareas
# - **Eficiencia**: Menos tokens utilizados
# - **Generalización**: Funciona para tareas diversas
#
# ### Limitaciones:
# - **Inconsistencia**: Resultados pueden variar más
# - **Formato**: Menos control sobre la estructura de salida
# - **Tareas complejas**: Puede requerir instrucciones muy detalladas
# - **Dominio específico**: Menos efectivo en nichos especializados

# %%
# Configuración inicial
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage
import os
import re
import time

# Configurar el modelo
llm = ChatOpenAI(
    base_url=os.getenv("OPENAI_BASE_URL"),
    api_key=os.getenv("GITHUB_TOKEN"),
    model="gpt-4o",
    temperature=0.7  # Balance entre creatividad y consistencia
)

print("✓ Modelo configurado para zero-shot prompting")
# Out:
# ✓ Modelo configurado para zero-shot prompting

# %% [markdown]
# ## Anatomía de un Prompt Zero-Shot Efectivo
#
# Un prompt zero-shot efectivo tiene estos componentes:
#
# 1. **Contexto/Rol**: Quién debe "ser" el modelo
# 2. **Tarea**: Qué debe hacer específicamente
# 3. **Formato**: Cómo debe estructurar la respuesta
# 4. **Restricciones**: Qué debe evitar o considerar
# 5. **Input**: Los datos específicos a procesar

# %%
# Ejemplo básico vs mejorado
def comparar_prompts_basico():
    texto = "El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto."
    
    # Prompt básico (menos efectivo)
    prompt_basico = f"Analiza este texto: {texto}"
    
    # Prompt mejorado (más efectivo)
    prompt_mejorado = f"""Eres un analista de sentimientos experto. 
    
Tarea: Analiza el sentimiento del siguiente texto sobre un producto.
    
Formato de respuesta:
- Sentimiento general: [Positivo/Negativo/Neutral]
- Aspectos positivos: [lista]
- Aspectos negativos: [lista]
- Puntuación de confianza: [0-10]
    
Texto a analizar: "{texto}"""
    
    print("=== COMPARACIÓN DE PROMPTS ===")
    
    # Probar prompt básico
    print("\n1. PROMPT BÁSICO:")
    print(f"Prompt: {prompt_basico}")
    try:
        response1 = llm.invoke([HumanMessage(content=prompt_basico)])
        print(f"Respuesta: {response1.content}")
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n" + "-"*60)
    
    # Probar prompt mejorado
    print("\n2. PROMPT MEJORADO:")
    print(f"Prompt: {prompt_mejorado[:100]}...")
    try:
        response2 = llm.invoke([HumanMessage(content=prompt_mejorado)])
        print(f"Respuesta: {response2.content}")
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n=== ANÁLISIS ===")
    print("• Prompt básico: Ambiguo, respuesta poco estructurada")
    print("• Prompt mejorado: Específico, respuesta estructurada y útil")

# Ejecutar comparación
comparar_prompts_basico()
# Out:
# === COMPARACIÓN DE PROMPTS ===
#
# 1. PROMPT BÁSICO:
# Prompt: Analiza este texto: El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto.
# Respuesta: Claro, aquí tienes un análisis del texto:
#
# 1. **Descripción de características positivas**:
#    - **Batería increíble**: El término "increíble" sugiere un desempeño sobresaliente en la duración o eficiencia de la batería. Es un atributo destacado y valorado por los usuarios.
#    - **Cámara fantástica**: La palabra "fantástica" indica que la calidad de la cámara es excepcional, posiblemente en términos de resolución, funciones avanzadas o innovación tecnológica.
#
# 2. **Crítica negativa**:
#    - **Precio muy alto**: Este es el único elemento negativo destacado en el texto. El uso de "muy alto" enfatiza que el costo del dispositivo puede ser prohibitivo o desproporcionado en relación con las expectativas o el mercado.
#
# 3. **Tono general**:
#    - El texto tiene un tono equilibrado, señalando tanto aspectos positivos como negativos. Sin embargo, el precio parece ser un factor limitante que podría afectar la percepción global del producto.
#
# 4. **Implicaciones subyacentes**:
#    - Aunque se reconocen las ventajas tecnológicas del iPhone (batería y cámara), el costo podría ser un obstáculo para algunos consumidores. Esto sugiere que el público objetivo podría estar limitado a aquellos dispuestos a pagar una prima significativa por la calidad y las innovaciones.
#
# En resumen, el texto elogia las características técnicas del nuevo iPhone, pero cuestiona su accesibilidad debido al alto precio, lo que refleja una percepción típica en torno a productos premium de Apple.
#
# ------------------------------------------------------------
#
# 2. PROMPT MEJORADO:
# Prompt: Eres un analista de sentimientos experto.
#
# Tarea: Analiza el sentimiento del siguiente texto sobre ...
# Respuesta: - **Sentimiento general:** Neutral
# - **Aspectos positivos:**
#   1. La batería es increíble.
#   2. La cámara es fantástica.
# - **Aspectos negativos:**
#   1. El precio es muy alto.
# - **Puntuación de confianza:** 9
#
# === ANÁLISIS ===
# • Prompt básico: Ambiguo, respuesta poco estructurada
# • Prompt mejorado: Específico, respuesta estructurada y útil

# %% [markdown]
# ## Técnicas de Zero-Shot por Tipo de Tarea
#
# Diferentes tipos de tareas requieren enfoques específicos en zero-shot prompting.

# %%
# 1. CLASIFICACIÓN
def zero_shot_clasificacion():
    print("=== ZERO-SHOT PARA CLASIFICACIÓN ===")
    
    emails = [
        "Reunión de equipo mañana a las 10 AM en sala de conferencias",
        "¡Felicidades! Has ganado $1,000,000! Haz clic aquí ahora",
        "Recordatorio: Tu factura de internet vence en 3 días"
    ]
    
    # Prompt optimizado para clasificación
    clasificacion_prompt = """Eres un clasificador de emails empresariales.
    
Clasifica cada email en una de estas categorías:
- TRABAJO: Relacionado con tareas laborales
- SPAM: Contenido no solicitado o sospechoso
- PERSONAL: Asuntos personales o administrativos

Responde solo con el nombre de la categoría.

Email: "{}"
Categoría:"""
    
    for i, email in enumerate(emails, 1):
        prompt = clasificacion_prompt.format(email)
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            print(f"{i}. Email: {email[:50]}...")
            print(f"   Clasificación: {response.content.strip()}\n")
        except Exception as e:
            print(f"Error en email {i}: {e}")

# Ejecutar clasificación
zero_shot_clasificacion()
# Out:
# === ZERO-SHOT PARA CLASIFICACIÓN ===
# 1. Email: Reunión de equipo mañana a las 10 AM en sala de co...
#    Clasificación: TRABAJO
#
# 2. Email: ¡Felicidades! Has ganado $1,000,000! Haz clic aquí...
#    Clasificación: SPAM
#
# 3. Email: Recordatorio: Tu factura de internet vence en 3 dí...
#    Clasificación: PERSONAL

# %%
# 2. GENERACIÓN DE CONTENIDO
def zero_shot_generacion():
    print("=== ZERO-SHOT PARA GENERACIÓN ===")
    
    # Prompt estructurado para generación
    generacion_prompt = """Eres un copywriter creativo especializado en redes sociales.
    
Tarea: Crear un post para LinkedIn sobre el tema dado.
    
Requisitos:
- Tono profesional pero accesible
- Máximo 150 palabras
- Incluir 1-2 hashtags relevantes
- Hacer una pregunta para fomentar engagement
    
Tema: "Importancia del aprendizaje continuo en tecnología"
    
Post para LinkedIn:"""
    
    try:
        response = llm.invoke([HumanMessage(content=generacion_prompt)])
        print("Post generado:")
        print("-" * 40)
        print(response.content)
        print("-" * 40)
        
        # Análisis del resultado
        words = len(response.content.split())
        hashtags = response.content.count('#')
        questions = response.content.count('?')
        
        print(f"\nAnálisis:")
        print(f"• Palabras: {words} (límite: 150)")
        print(f"• Hashtags: {hashtags}")
        print(f"• Preguntas: {questions}")
        print(f"• Cumple requisitos: {'✓' if words <= 150 and hashtags >= 1 and questions >= 1 else '✗'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación
zero_shot_generacion()
# Out:
# === ZERO-SHOT PARA GENERACIÓN ===
# Post generado:
# ----------------------------------------
# 🚀 **El aprendizaje continuo: tu mejor aliado en un mundo tecnológico en constante cambio** 🌐
#
# En tecnología, lo que hoy es tendencia, mañana podría ser obsoleto. Por eso, invertir en aprendizaje continuo no es una opción, ¡es una necesidad! 📚💡
#
# Ya sea que estés perfeccionando tus habilidades en inteligencia artificial, aprendiendo un nuevo lenguaje de programación o siguiendo de cerca las últimas innovaciones, mantenerte actualizado no solo te hace más competitivo, sino también más adaptable a los cambios del mercado.
#
# El conocimiento es poder, pero en tecnología, la capacidad de aprender rápidamente es *superpoder*. 💪
#
# 👉 **¿Qué nuevo conocimiento o habilidad estás aprendiendo para mantenerte a la vanguardia?**
#
# Comparte tu experiencia en los comentarios y sigamos creciendo juntos. 🌟
#
# #AprendizajeContinuo #Tecnología
# ----------------------------------------
#
# Análisis:
# • Palabras: 121 (límite: 150)
# • Hashtags: 2
# • Preguntas: 1
# • Cumple requisitos: ✓

# %%
# 3. EXTRACCIÓN DE INFORMACIÓN
def zero_shot_extraccion():
    print("=== ZERO-SHOT PARA EXTRACCIÓN ===")
    
    # Texto de ejemplo
    texto_noticia = """Apple Inc. anunció hoy que su CEO Tim Cook se reunirá con inversores 
    el próximo 15 de marzo de 2024 en Cupertino, California. La reunión abordará los 
    resultados financieros del Q1 2024, donde la compañía reportó ingresos de $89.5 
    billones. Cook también discutirá la nueva estrategia de IA de Apple y el lanzamiento 
    del iPhone 16 programado para septiembre. Las acciones de Apple (AAPL) subieron 
    3.2% tras el anuncio."""
    
    # Prompt para extracción estructurada
    extraccion_prompt = f"""Eres un analista financiero experto en extraer datos clave.
    
Extrae la siguiente información del texto dado:
    
Formato de respuesta (JSON):
{{
  "empresa": "nombre de la empresa",
  "ceo": "nombre del CEO",
  "fecha_evento": "fecha del evento",
  "ubicacion": "ubicación del evento",
  "ingresos": "cifra de ingresos mencionada",
  "productos": ["lista de productos mencionados"],
  "cambio_acciones": "porcentaje de cambio en acciones"
}}
    
Texto: "{texto_noticia}"
    
JSON:"""
    
    try:
        response = llm.invoke([HumanMessage(content=extraccion_prompt)])
        print("Información extraída:")
        print(response.content)
        
        # Intentar parsear como JSON para validar formato
        import json
        try:
            raw = response.content.strip()
            match = re.search(r'```(?:json)?\s*([\s\S]*?)\s*```', raw)
            cleaned = match.group(1) if match else raw
            data = json.loads(cleaned)
            print("\n✓ Formato JSON válido")
            print(f"✓ Campos extraídos: {len(data)} elementos")
        except:
            print("\n✗ Formato JSON inválido - necesita refinamiento del prompt")
            
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar extracción
zero_shot_extraccion()
# Out:
# === ZERO-SHOT PARA EXTRACCIÓN ===
# Información extraída:
# ```json
# {
#   "empresa": "Apple Inc.",
#   "ceo": "Tim Cook",
#   "fecha_evento": "15 de marzo de 2024",
#   "ubicacion": "Cupertino, California",
#   "ingresos": "$89.5 billones",
#   "productos": ["iPhone 16"],
#   "cambio_acciones": "3.2%"
# }
# ```
#
# ✓ Formato JSON válido
# ✓ Campos extraídos: 7 elementos

# %% [markdown]
# ## Optimización de Prompts Zero-Shot
#
# Técnicas para mejorar la efectividad de prompts zero-shot.

# %%
# Técnica 1: Prompts con Roles Específicos
def roles_especificos():
    print("=== OPTIMIZACIÓN: ROLES ESPECÍFICOS ===")
    
    pregunta = "¿Cómo puedo mejorar el rendimiento de mi aplicación web?"
    
    roles = {
        "Genérico": "Responde la siguiente pregunta:",
        "Desarrollador Senior": "Eres un desarrollador senior con 10 años de experiencia en optimización web. Responde como un experto:",
        "Consultor de Performance": "Eres un consultor especializado en performance web que ha optimizado cientos de aplicaciones. Proporciona una respuesta detallada y técnica:",
        "CTO": "Eres un CTO de una startup tecnológica. Responde con una perspectiva estratégica y técnica balanceada:"
    }
    
    for rol, contexto in roles.items():
        prompt = f"{contexto}\n\n{pregunta}"
        
        print(f"\n{rol.upper()}:")
        print("-" * 30)
        
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            # Mostrar solo las primeras líneas para comparación
            preview = response.content[:200] + "..." if len(response.content) > 200 else response.content
            print(preview)
        except Exception as e:
            print(f"Error: {e}")
    
    print("\n=== OBSERVACIONES ===")
    print("• Roles específicos generan respuestas más enfocadas")
    print("• La experticia del rol influye en la profundidad técnica")
    print("• El contexto profesional afecta el tipo de soluciones propuestas")

# Ejecutar ejemplo de roles
roles_especificos()
# Out:
# === OPTIMIZACIÓN: ROLES ESPECÍFICOS ===
#
# GENÉRICO:
# ------------------------------
# Mejorar el rendimiento de tu aplicación web es un proceso clave para garantizar una buena experiencia de usuario, reducir tiempos de carga y optimizar el uso de recursos. A continuación, te comparto u...
#
# DESARROLLADOR SENIOR:
# ------------------------------
# Mejorar el rendimiento de tu aplicación web requiere un enfoque estratégico y multidimensional. Aquí tienes una lista de prácticas avanzadas que puedes implementar, basadas en mis 10 años de experienc...
#
# CONSULTOR DE PERFORMANCE:
# ------------------------------
# Optimizar el rendimiento de una aplicación web es un proceso técnico que implica atacar diversos frentes: desde la arquitectura del servidor hasta la experiencia del usuario en el navegador. A continu...
#
# CTO:
# ------------------------------
# Mejorar el rendimiento de tu aplicación web requiere un enfoque estratégico y técnico bien equilibrado. Aquí tienes un plan estructurado para abordar el problema:
#
# ---
#
# ### **1. Diagnóstico y Análisis...
#
# === OBSERVACIONES ===
# • Roles específicos generan respuestas más enfocadas
# • La experticia del rol influye en la profundidad técnica
# • El contexto profesional afecta el tipo de soluciones propuestas

# %%
# Técnica 2: Instrucciones Graduales
def instrucciones_graduales():
    print("=== OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===")
    
    # Problema complejo para demostrar
    problema = "Necesito crear una estrategia de marketing digital para lanzar una nueva app de fitness"
    
    # Prompt con instrucciones graduales
    prompt_gradual = f"""Eres un estratega de marketing digital senior.
    
Problema: {problema}
    
Desarrolla una estrategia siguiendo este proceso paso a paso:
    
PASO 1: Análisis inicial
- Identifica el público objetivo
- Define 3 puntos de valor únicos de la app
    
PASO 2: Canales de marketing
- Selecciona 4-5 canales digitales más efectivos
- Justifica cada selección
    
PASO 3: Estrategia de contenido
- Define tipos de contenido para cada canal
- Sugiere frecuencia de publicación
    
PASO 4: Métricas y KPIs
- Define 5 métricas clave para medir éxito
- Sugiere herramientas de medición
    
Desarrolla cada paso con detalle:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_gradual)])
        print("ESTRATEGIA DESARROLLADA:")
        print("=" * 50)
        print(response.content)
        
        # Análisis de estructura
        pasos_detectados = response.content.count("PASO")
        secciones = ["análisis", "canales", "contenido", "métricas"]
        secciones_encontradas = sum(1 for seccion in secciones if seccion.lower() in response.content.lower())
        
        print("\n=== ANÁLISIS DE ESTRUCTURA ===")
        print(f"• Pasos identificados: {pasos_detectados}/4")
        print(f"• Secciones cubiertas: {secciones_encontradas}/4")
        print(f"• Estructura seguida: {'✓' if pasos_detectados >= 3 else '✗'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar instrucciones graduales
instrucciones_graduales()
# Out:
# === OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===
# ESTRATEGIA DESARROLLADA:
# ==================================================
# ### Estrategia de Marketing Digital para el Lanzamiento de una App de Fitness
#
# #### **PASO 1: Análisis Inicial**
#
# 1. **Identificación del Público Objetivo:**
#    - **Segmentación demográfica:**
#      - Edad: 18-40 años (jóvenes y adultos en busca de mejorar su estado físico).
#      - Género: Hombres y mujeres, con un ligero enfoque en mujeres (estadísticamente más interesadas en aplicaciones de fitness).
#      - Ubicación: Principalmente en zonas urbanas y suburbanas con acceso a tecnología y gimnasios.
#    - **Segmentación psicográfica:**
#      - Personas interesadas en el fitness, el bienestar, la salud y el crecimiento personal.
#      - Usuarios que buscan soluciones asequibles y flexibles para entrenar en casa o en el gimnasio.
#      - Personas que valoran la tecnología y los datos para optimizar su rendimiento físico.
#    - **Segmentación conductual:**
#      - Usuarios móviles activos que ya han descargado otras aplicaciones de fitness o bienestar.
#      - Personas que tienen problemas para mantener la motivación en sus rutinas de ejercicio.
#      - Personas que buscan programas de fitness personalizados.
#
# 2. **Tres Puntos de Valor Únicos de la App:**
#    - **Personalización Inteligente:** La app utiliza inteligencia artificial para crear planes de entrenamiento y nutrición personalizados basados en los objetivos, nivel de fitness y preferencias del usuario.
#    - **Gamificación:** Incluye desafíos, recompensas y medallas digitales para mantener la motivación y fomentar la adherencia a los objetivos de fitness.
#    - **Compatibilidad Multiplataforma:** Se integra con dispositivos wearables (Apple Watch, Fitbit, etc.), aplicaciones de nutrición y calendarios personales para un seguimiento completo y automatizado.
#
# ---
#
# #### **PASO 2: Canales Digitales de Marketing**
#
# 1. **Instagram:**
#    - **Justificación:** Es una plataforma visual ideal para mostrar contenido relacionado con el fitness, como ejercicios, transformaciones, retos y testimonios. Además, tiene un alto engagement en el público objetivo.
#    - **Estrategia:** Publicaciones de inspiración, videos cortos de entrenamientos, historias interactivas y colaboraciones con influencers fitness.
#
# 2. **YouTube:**
#    - **Justificación:** Es el segundo motor de búsqueda más grande y la plataforma perfecta para tutoriales detallados de ejercicios, demostraciones de la app y contenido educativo.
#    - **Estrategia:** Crear un canal temático con rutinas de ejercicios gratuitas, tips de nutrición y guías de uso de la app.
#
# 3. **Google Ads (Búsqueda y Display):**
#    - **Justificación:** La publicidad en Google permite captar usuarios que ya están buscando activamente soluciones de fitness, así como mostrar anuncios visuales en webs relacionadas con salud.
#    - **Estrategia:** Anuncios de búsqueda para palabras clave como "mejor app de fitness", "entrenamientos personalizados" y "planes de ejercicio en casa". Anuncios de display en sitios web de fitness y bienestar.
#
# 4. **TikTok:**
#    - **Justificación:** Es la plataforma ideal para atraer a un público más joven con contenido dinámico y viral relacionado con tendencias de fitness.
#    - **Estrategia:** Publicar videos cortos de entrenamientos, retos fitness y colaboraciones con microinfluencers.
#
# 5. **Email Marketing:**
#    - **Justificación:** Es un canal efectivo para retener usuarios, enviar recordatorios y ofrecer contenido exclusivo como ebooks de nutrición o entrenamientos especiales.
#    - **Estrategia:** Campañas de onboarding para nuevos usuarios, newsletters semanales con tips y promociones, y correos personalizados basados en el progreso del usuario.
#
# ---
#
# #### **PASO 3: Estrategia de Contenido**
#
# 1. **Para Instagram:**
#    - **Tipos de contenido:**
#      - Reels con rutinas de ejercicios en 1 minuto.
#      - Historias destacadas de usuarios que lograron resultados usando la app.
#      - Carruseles educativos sobre técnicas de entrenamiento y consejos de nutrición.
#    - **Frecuencia:**
#      - 3-4 publicaciones por semana.
#      - Historias diarias.
#      - Colaboraciones con influencers: 1 vez por semana.
#
# 2. **Para YouTube:**
#    - **Tipos de contenido:**
#      - Videos de 5-10 minutos con entrenamientos completos.
#      - Tutoriales sobre cómo usar las funciones de la app.
#      - Recopilaciones de testimonios y casos de éxito.
#    - **Frecuencia:**
#      - 1-2 videos por semana.
#
# 3. **Para Google Ads:**
#    - **Tipos de contenido:**
#      - Anuncios de texto optimizados para búsquedas relevantes.
#      - Banners visuales atractivos con capturas de pantalla de la app y testimonios.
#    - **Frecuencia:**
#      - Campañas siempre activas, ajustando el presupuesto semanalmente según los resultados.
#
# 4. **Para TikTok:**
#    - **Tipos de contenido:**
#      - Retos fitness virales (por ejemplo, "30 días de abdominales").
#      - Trucos rápidos de entrenamiento o nutrición.
#      - Colaboraciones con microinfluencers y creadores de contenido.
#    - **Frecuencia:**
#      - 5-6 publicaciones por semana.
#
# 5. **Para Email Marketing:**
#    - **Tipos de contenido:**
#      - Correos de bienvenida con tutoriales de la app.
#      - Recordatorios personalizados para cumplir objetivos.
#      - Promociones, descuentos y desafíos exclusivos.
#    - **Frecuencia:**
#      - 1-2 correos por semana.
#
# ---
#
# #### **PASO 4: Métricas y KPIs**
#
# 1. **Métricas Clave:**
#    - **Descargas de la App:** Número de descargas totales en App Store y Google Play.
#    - **Usuarios Activos Diarios y Mensuales (DAU/MAU):** Indicador de la retención y uso de la app.
#    - **Tasa de Conversión de Anuncios:** % de usuarios que descargan la app tras ver un anuncio.
#    - **Engagement en Redes Sociales:** Incluye likes, comentarios, compartidos y visualizaciones.
#    - **Tasa de Retención:** % de usuarios que continúan usando la app después de 30 y 90 días.
#
# 2. **Herramientas de Medición:**
#    - **Google Analytics y Firebase:** Para medir las descargas, el comportamiento de los usuarios en la app y el embudo de conversión.
#    - **Hootsuite o Buffer:** Para analizar el engagement en redes sociales.
#    - **TikTok Analytics y YouTube Studio:** Para métricas específicas de cada plataforma.
#    - **Google Ads Manager:** Para medir la efectividad de las campañas de Google Ads.
#    - **Email Marketing Tools (Ej. Mailchimp o Klaviyo):** Para analizar tasas de apertura, clics y conversión de emails.
#
# ---
#
# ### **Resumen**
#
# Esta estrategia integral combina una comprensión profunda del público objetivo con una selección cuidadosa de canales digitales relevantes, respaldada por contenido atractivo y medición constante de resultados. El uso de múltiples plataformas y la personalización del contenido garantizarán un lanzamiento impactante y sostenible para la app de fitness.
#
# === ANÁLISIS DE ESTRUCTURA ===
# • Pasos identificados: 4/4
# • Secciones cubiertas: 4/4
# • Estructura seguida: ✓

# %% [markdown]
# ## Casos de Uso Avanzados
#
# Aplicaciones más sofisticadas de zero-shot prompting.

# %%
# Caso de uso: Análisis de código
def analisis_codigo_zero_shot():
    print("=== CASO DE USO: ANÁLISIS DE CÓDIGO ===")
    
    codigo_ejemplo = '''def process_user_data(users):
    result = []
    for user in users:
        if user["age"] > 18:
            result.append({
                "name": user["name"].upper(),
                "email": user["email"],
                "status": "adult"
            })
    return result'''
    
    prompt_analisis = f"""Eres un senior code reviewer con experiencia en Python.
    
Analiza el siguiente código y proporciona:
    
1. FUNCIONALIDAD:
   - ¿Qué hace este código?
   - ¿Cuál es su propósito?
    
2. PROBLEMAS POTENCIALES:
   - Errores de lógica
   - Vulnerabilidades de seguridad
   - Problemas de rendimiento
    
3. MEJORAS SUGERIDAS:
   - Optimizaciones de código
   - Mejores prácticas
   - Manejo de errores
    
4. PUNTUACIÓN DE CALIDAD: [1-10]
    
Código a analizar:
```python
{codigo_ejemplo}
```
    
Análisis:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_analisis)])
        print("ANÁLISIS DE CÓDIGO:")
        print("=" * 50)
        print(response.content)
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis de código
analisis_codigo_zero_shot()
# Out:
# === CASO DE USO: ANÁLISIS DE CÓDIGO ===
# ANÁLISIS DE CÓDIGO:
# ==================================================
# ### 1. FUNCIONALIDAD:
#
# **¿Qué hace este código?**
# - La función `process_user_data` toma una lista de diccionarios (`users`) como entrada. Cada diccionario representa un usuario y contiene al menos las claves `"name"`, `"email"`, y `"age"`.
# - Filtra a los usuarios cuya edad es mayor a 18 (`user["age"] > 18`).
# - Para cada usuario filtrado, crea un nuevo diccionario con las siguientes claves:
#   - `"name"`: El nombre del usuario en mayúsculas (`user["name"].upper()`).
#   - `"email"`: El email del usuario sin modificaciones.
#   - `"status"`: Un estado fijo con el valor `"adult"`.
# - Devuelve una lista (`result`) con los diccionarios procesados.
#
# **¿Cuál es su propósito?**
# - Transformar y filtrar datos de usuarios, específicamente para identificar a los mayores de 18 años y enriquecer sus datos con un estado (`"adult"`) y un nombre en mayúsculas. Este tipo de funcionalidad podría ser útil en sistemas que necesitan categorizar usuarios (e.g., segmentación por edad para marketing o regulaciones).
#
# ---
#
# ### 2. PROBLEMAS POTENCIALES:
#
# #### **Errores de lógica:**
# 1. Suposición sobre la estructura de los datos:
#    - La función asume que cada diccionario en la lista tiene las claves `"name"`, `"email"`, y `"age"`. Si alguno falta, se generará un error de tipo `KeyError`.
#    - La función no verifica que el valor de `"age"` sea un número. Si un valor no numérico (e.g., una cadena) está presente, se generará un error de tipo `TypeError`.
#
# 2. Inclusión silenciosa de valores no válidos:
#    - No se valida que `"email"` sea una dirección de correo válida.
#
# #### **Vulnerabilidades de seguridad:**
# 1. **Posible exposición de datos sensibles:**
#    - La función devuelve la dirección de correo electrónico tal cual fue recibida. Si el sistema que usa esta función interactúa con datos sensibles, esto podría ser un problema en términos de privacidad.
#
# 2. **Falta de sanitización de datos:**
#    - La función no sanitiza entradas como `"name"` o `"email"`, lo que podría resultar en problemas si estas se usan posteriormente en contextos como HTML (riesgo de inyección XSS) o bases de datos (riesgo de inyección SQL).
#
# #### **Problemas de rendimiento:**
# 1. Ineficiencia en listas grandes:
#    - Para listas muy grandes, el uso de bucles explícitos y operaciones como `.upper()` en cada iteración puede ser costoso en términos de tiempo. Aunque no es un problema grave para listas pequeñas o medianas, puede escalar mal.
#
# ---
#
# ### 3. MEJORAS SUGERIDAS:
#
# #### **Optimizaciones de código:**
# 1. **Uso de listas por comprensión:**
#    - La lógica actual puede reescribirse como una lista por comprensión, lo que hace el código más compacto y posiblemente más eficiente.
#      ```python
#      return [
#          {"name": user["name"].upper(), "email": user["email"], "status": "adult"}
#          for user in users
#          if user.get("age", 0) > 18
#      ]
#      ```
#
# 2. **Validación de datos opcional:**
#    - Usar `dict.get()` con valores predeterminados puede evitar errores de claves faltantes.
#
# #### **Mejores prácticas:**
# 1. **Validación de entrada:**
#    - Verificar que cada usuario tenga las claves necesarias y que los valores sean del tipo esperado.
#    - Por ejemplo:
#      ```python
#      if not isinstance(user.get("age"), int):
#          continue
#      ```
#
# 2. **Sanitización de datos:**
#    - Sanitizar la entrada, especialmente `"email"` y `"name"`, si se procesarán más adelante.
#
# 3. **Manejo de errores:**
#    - Incluir un manejo explícito de errores para entradas mal formateadas. Por ejemplo, agregar un bloque `try...except` para evitar que errores individuales interrumpan el procesamiento completo:
#      ```python
#      try:
#          if user["age"] > 18:
#              result.append({
#                  "name": user["name"].upper(),
#                  "email": user["email"],
#                  "status": "adult"
#              })
#      except (KeyError, TypeError):
#          pass  # O registrar el error para su posterior revisión
#      ```
#
# 4. **Validación de correos electrónicos:**
#    - Utilizar una librería como `email_validator` para asegurarse de que el campo `"email"` contiene una dirección válida:
#      ```python
#      from email_validator import validate_email, EmailNotValidError
#
#      try:
#          validate_email(user["email"])
#      except EmailNotValidError:
#          continue
#      ```
#
# #### **Manejo de datos sensibles:**
# - Si `"email"` es un dato sensible, considerar omitirlo o anonimizarlo en la salida.
#
# ---
#
# ### 4. PUNTUACIÓN DE CALIDAD: **6/10**
#
# #### **Criterios evaluados:**
# 1. **Funcionalidad (3/3):**
#    - El código cumple con su propósito y es funcional para entradas correctas.
#
# 2. **Legibilidad (2.5/3):**
#    - El código es legible, aunque podría beneficiarse de una lista por comprensión para mayor claridad.
#
# 3. **Robustez (0.5/2):**
#    - No gestiona errores ni valida datos, lo que puede llevar a fallos en escenarios reales.
#
# 4. **Seguridad (0.5/1):**
#    - No maneja posibles vulnerabilidades como datos no sanitizados.
#
# 5. **Rendimiento (0.5/1):**
#    - El rendimiento es aceptable, pero no está optimizado para grandes conjuntos de datos.
#
# ---
#
# ### **Resumen de acciones recomendadas:**
# 1. Reescribir el bucle como una lista por comprensión.
# 2. Implementar validaciones de entrada (claves, tipos, valores razonables).
# 3. Manejar errores explícitamente para evitar interrupciones.
# 4. Sanitizar datos sensibles (e.g., nombres y correos electrónicos).
# 5. Considerar el uso de librerías externas para la validación de correos electrónicos si es crítico.

# %%
# Caso de uso: Generación de tests
def generacion_tests_zero_shot():
    print("=== CASO DE USO: GENERACIÓN DE TESTS ===")
    
    funcion_a_testear = '''def calculate_discount(price, discount_percent, user_type):
    """Calculate final price after discount.
    
    Args:
        price (float): Original price
        discount_percent (float): Discount percentage (0-100)
        user_type (str): 'premium' or 'regular'
        
    Returns:
        float: Final price after discount
    """
    if user_type == 'premium':
        discount_percent += 5  # Extra 5% for premium users
    
    discount_amount = price * (discount_percent / 100)
    return price - discount_amount'''
    
    prompt_tests = f"""Eres un QA engineer experto en testing de Python.
    
Genera tests unitarios completos para la siguiente función usando pytest.
    
Incluye tests para:
1. Casos normales (diferentes tipos de usuario y descuentos)
2. Casos edge (descuento 0%, 100%, valores negativos)
3. Casos de error (tipos incorrectos, valores inválidos)
4. Tests parametrizados cuando sea apropiado
    
Función a testear:
```python
{funcion_a_testear}
```
    
Genera código de test completo y ejecutable:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_tests)])
        print("TESTS GENERADOS:")
        print("=" * 50)
        print(response.content)
        
        # Análisis básico de los tests generados
        test_methods = response.content.count("def test_")
        assertions = response.content.count("assert")
        parametrize = response.content.count("@pytest.mark.parametrize")
        
        print("\n=== ANÁLISIS DE TESTS ===")
        print(f"• Métodos de test: {test_methods}")
        print(f"• Assertions: {assertions}")
        print(f"• Tests parametrizados: {parametrize}")
        print(f"• Cobertura estimada: {'Alta' if test_methods >= 5 else 'Media' if test_methods >= 3 else 'Baja'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación de tests
generacion_tests_zero_shot()
# Out:
# === CASO DE USO: GENERACIÓN DE TESTS ===
# TESTS GENERADOS:
# ==================================================
# A continuación se presenta el código de test completo y ejecutable para la función `calculate_discount` usando `pytest`. Este incluye casos normales, edge cases, casos de error, y tests parametrizados.
#
# ### Código de tests
#
# ```python
# import pytest
# from calculate_discount import calculate_discount  # Asegúrate de que el archivo esté en el mismo directorio o ajusta el import
#
# # Tests parametrizados para casos normales y edge cases
# @pytest.mark.parametrize(
#     "price, discount_percent, user_type, expected",
#     [
#         # Casos normales
#         (100.0, 10.0, 'regular', 90.0),  # 10% descuento regular
#         (200.0, 20.0, 'premium', 150.0),  # 20% descuento + 5% extra premium
#         (50.0, 0.0, 'regular', 50.0),  # Sin descuento regular
#         (50.0, 0.0, 'premium', 47.5),  # Sin descuento pero premium obtiene 5%
#         (100.0, 100.0, 'regular', 0.0),  # Descuento total regular
#
#         # Casos edge
#         (100.0, -10.0, 'regular', 110.0),  # Descuento negativo (se suma al precio)
#         (100.0, 0.0, 'premium', 95.0),  # 0% descuento pero premium obtiene 5%
#         (100.0, 100.0, 'premium', -5.0),  # 100% descuento + 5% extra premium
#         (0.0, 50.0, 'regular', 0.0),  # Precio 0 con descuento
#         (0.0, 50.0, 'premium', -0.0),  # Precio 0 con descuento premium
#     ],
# )
# def test_calculate_discount_normal_and_edge(price, discount_percent, user_type, expected):
#     assert calculate_discount(price, discount_percent, user_type) == pytest.approx(expected)
#
#
# # Tests de casos de error
# @pytest.mark.parametrize(
#     "price, discount_percent, user_type, expected_exception",
#     [
#         ('100', 10.0, 'regular', TypeError),  # Tipo incorrecto para precio
#         (100.0, '10', 'regular', TypeError),  # Tipo incorrecto para descuento
#         (100.0, 10.0, 123, TypeError),  # Tipo incorrecto para user_type
#         (100.0, 10.0, 'unknown', ValueError),  # Tipo de usuario inválido
#         (-100.0, 10.0, 'regular', ValueError),  # Precio negativo
#     ],
# )
# def test_calculate_discount_errors(price, discount_percent, user_type, expected_exception):
#     with pytest.raises(expected_exception):
#         calculate_discount(price, discount_percent, user_type)
#
#
# # Tests para cubrir comportamiento adicional
# def test_calculate_discount_extra_behavior():
#     # Caso donde el descuento supera el 100%
#     assert calculate_discount(100.0, 105.0, 'regular') == pytest.approx(-5.0)
#     assert calculate_discount(100.0, 105.0, 'premium') == pytest.approx(-10.0)
#
#     # Caso donde `user_type` es insensible a mayúsculas/minúsculas
#     assert calculate_discount(100.0, 10.0, 'PREMIUM') == pytest.approx(85.0)
#     assert calculate_discount(100.0, 10.0, 'Regular') == pytest.approx(90.0)
#
#
# # Casos adicionales (si se desea manejar inputs no estándar)
# @pytest.mark.parametrize(
#     "price, discount_percent, user_type, expected",
#     [
#         (100.0, 10.0, 'PREMIUM', 85.0),  # User type insensible a mayúsculas
#         (100.0, 10.0, 'premium ', 85.0),  # User type con espacios adicionales
#     ],
# )
# def test_calculate_discount_input_variants(price, discount_percent, user_type, expected):
#     assert calculate_discount(price, discount_percent.strip(), user_type.strip()) == pytest.approx(expected)
# ```
#
# ### Notas importantes:
# 1. **Casos normales**: Se cubrieron situaciones estándar con diferentes combinaciones de precios, porcentajes de descuento y tipos de usuarios.
# 2. **Casos edge**: Incluyen valores extremos como descuentos de 0%, 100%, valores negativos, y precios cero.
# 3. **Casos de error**: Se manejan errores de tipo, valores inválidos (como precios negativos o tipos de usuario desconocidos), y se espera que la función arroje excepciones adecuadas (`TypeError` o `ValueError`).
# 4. **Tests parametrizados**: Usamos `pytest.mark.parametrize` para reducir la redundancia en los tests y cubrir múltiples casos con una sola función.
# 5. **Comportamiento adicional**: Se añadieron tests para manejar entradas insensibles a mayúsculas o con espacios extra.
#
# ### Ejecución
# Para ejecutar estos tests, guarda el código en un archivo (por ejemplo, `test_calculate_discount.py`) y ejecuta el siguiente comando en tu terminal:
#
# ```bash
# pytest test_calculate_discount.py
# ```
#
# Esto ejecutará todos los casos y mostrará un resumen de los resultados.
#
# === ANÁLISIS DE TESTS ===
# • Métodos de test: 4
# • Assertions: 6
# • Tests parametrizados: 3
# • Cobertura estimada: Media

# %% [markdown]
# ## Mejores Prácticas y Limitaciones
#
# ### ✅ Cuándo Usar Zero-Shot:
# - Tareas comunes y bien definidas
# - Cuando no tienes ejemplos disponibles
# - Para prototipado rápido
# - Tareas que requieren creatividad
#
# ### ❌ Cuándo NO Usar Zero-Shot:
# - Formatos de salida muy específicos
# - Tareas de dominio muy especializado
# - Cuando la consistencia es crítica
# - Tareas complejas que requieren patrones específicos
#
# ### 🎯 Mejores Prácticas:
# 1. **Sé específico**: Detalla exactamente qué quieres
# 2. **Define el formato**: Especifica cómo debe verse la salida
# 3. **Establece restricciones**: Qué debe evitar o considerar
# 4. **Usa roles**: Define quién debe "ser" el modelo
# 5. **Itera y refina**: Mejora basándote en resultados

# %%
# Ejercicio final: Diseña tu propio prompt zero-shot
def ejercicio_personalizado():
    print("=== EJERCICIO PERSONAL ===")
    print("\nDiseña un prompt zero-shot para esta tarea:")
    print("'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'")
    print("\nEstructura sugerida:")
    print("1. Rol/Contexto del modelo")
    print("2. Tarea específica")
    print("3. Requisitos del formato")
    print("4. Restricciones importantes")
    print("\nTu prompt aquí:")
    
    # Espacio para que el estudiante diseñe su prompt
    prompt_estudiante = """# COLOCA TU PROMPT AQUÍ
    
# Ejemplo de estructura:
# Eres un [ROL]...
# Tarea: [TAREA ESPECÍFICA]...
# Formato: [ESTRUCTURA DE SALIDA]...
# Restricciones: [LIMITACIONES]...
"""
    
    print(prompt_estudiante)
    
    # Prompt de ejemplo bien estructurado
    ejemplo_prompt = """Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
    
Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
    
Formato requerido:
- Título del puesto
- Resumen ejecutivo (2-3 líneas)
- Responsabilidades principales (4-5 puntos)
- Requisitos técnicos (separar esenciales de deseables)
- Beneficios y cultura de empresa
- Llamada a la acción
    
Restricciones:
- Máximo 400 palabras
- Lenguaje inclusivo y accesible
- Enfócate en crecimiento profesional
- Evita jerga técnica excesiva
- Sé honesto sobre el nivel junior
    
Descripción de trabajo:"""
    
    print("\n=== EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===")
    print(ejemplo_prompt)
    
    # Opcional: probar el prompt ejemplo
    print("\n¿Quieres ver el resultado del prompt ejemplo? (y/n)")
    # En un entorno real, aquí habría input del usuario
    
ejercicio_personalizado()
# Out:
# === EJERCICIO PERSONAL ===
#
# Diseña un prompt zero-shot para esta tarea:
# 'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'
#
# Estructura sugerida:
# 1. Rol/Contexto del modelo
# 2. Tarea específica
# 3. Requisitos del formato
# 4. Restricciones importantes
#
# Tu prompt aquí:
# # COLOCA TU PROMPT AQUÍ
#
# # Ejemplo de estructura:
# # Eres un [ROL]...
# # Tarea: [TAREA ESPECÍFICA]...
# # Formato: [ESTRUCTURA DE SALIDA]...
# # Restricciones: [LIMITACIONES]...
#
#
# === EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===
# Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
#
# Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
#
# Formato requerido:
# - Título del puesto
# - Resumen ejecutivo (2-3 líneas)
# - Responsabilidades principales (4-5 puntos)
# - Requisitos técnicos (separar esenciales de deseables)
# - Beneficios y cultura de empresa
# - Llamada a la acción
#
# Restricciones:
# - Máximo 400 palabras
# - Lenguaje inclusivo y accesible
# - Enfócate en crecimiento profesional
# - Evita jerga técnica excesiva
# - Sé honesto sobre el nivel junior
#
# Descripción de trabajo:
#
# ¿Quieres ver el resultado del prompt ejemplo? (y/n)

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Zero-shot prompting** es efectivo para tareas comunes sin necesidad de ejemplos
# 2. **Estructura clara** del prompt mejora significativamente los resultados
# 3. **Roles específicos** generan respuestas más enfocadas y expertas
# 4. **Instrucciones graduales** ayudan con tareas complejas
# 5. **Formato definido** asegura salidas consistentes y útiles
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos **Few-Shot Prompting**, donde aprenderemos a usar ejemplos específicos para guiar el comportamiento del modelo y lograr mayor consistencia en tareas especializadas.
#
# ### Para Practicar:
# 1. Diseña prompts zero-shot para diferentes tipos de tareas
# 2. Experimenta con diferentes roles y contextos
# 3. Compara resultados con y sin estructura específica
# 4. Mide la consistencia en múltiples ejecuciones
